% %%
graphics_toolkit ("gnuplot");

% %%
x = rand(1, 100);
y = rand(1, 100);

% %%
figure
plot(x, y ,'square');
ylabel('y-axis');
xlabel('x-axis');

% %%
w = -6 + sqrt(10) *(randn(1,10000))
% Out:
% w =
%
%  Columns 1 through 6:
%
%   -12.2432480   -6.9161461   -9.0740206   -8.3131840   -6.5051169   -0.3424573
%
%  Columns 7 through 12:
%
%    -4.9673347   -4.2142300   -8.7449760   -8.8953722   -5.0064636  -12.0742828
%
%  Columns 13 through 18:
%
%    -5.7214221   -3.8697827   -4.8196804   -5.5214085   -4.3292518   -3.8792506
%
%  Columns 19 through 24:
%
%    -5.4027710   -9.4022166   -5.6176767  -10.2903827   -8.0968766   -6.2340682
%
%  Columns 25 through 30:
%
%    -6.9229978   -1.3839389   -6.7615855   -8.5560685   -9.9893915  -11.0342994
%
%  Columns 31 through 36:
%
%   -10.9867694  -13.2328260    1.1659974  -11.0032155   -9.1599058   -4.3348931
%
%  Columns 37 through 42:
%
%    -6.1820409   -4.7127018   -1.6989588   -3.9036547   -6.4661639   -5.1146144
%
%  Columns 43 through 48:
%
%    -8.9355020   -9.3143896   -7.6030311   -8.1009112   -4.1182184   -6.4159892
%
%  Columns 49 through 54:
%
% ...

% %%
hist(w)

% %%
eye(3)
% Out:
% ans =
%
% Diagonal Matrix
%
%    1   0   0
%    0   1   0
%    0   0   1

% %%
ls
% Out:
% 'Graphics test.ipynb'

% %%
pwd
% Out:
% ans = /root/coursera-andrew-ng
